# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("global_house_purchase_dataset.csv")

# %%
df
# Out:
#      House_ID   Location  Bedrooms  Bathrooms  Balconies  Area_sqft  \
# 0       H0001    Kolkata         4          4          3       1398
# 1       H0002     Mumbai         3          4          2       1387
# 2       H0003       Pune         5          2          2       3395
# 3       H0004    Kolkata         1          4          3       3854
# 4       H0005  Hyderabad         5          4          2        808
# ...       ...        ...       ...        ...        ...        ...
# 1995    H1996    Chennai         1          3          2       1319
# 1996    H1997  Bangalore         1          1          0        674
# 1997    H1998    Chennai         1          3          2       1893
# 1998    H1999    Kolkata         2          4          2       2522
# 1999    H2000    Chennai         2          2          0       3273
#
#           Furnishing  Parking  Age_of_Property  Floor  Total_Floors  \
# 0     Semi-Furnished        2               14     14            12
# 1     Semi-Furnished        2                5      7             8
# 2     Semi-Furnished        2               26      4            19
# 3          Furnished        1               25      5            11
# 4     Semi-Furnished        0                3      8            14
# ...              ...      ...              ...    ...           ...
# 1995       Furnished        0                2      4            14
# 1996  Semi-Furnished        2               21     14             8
# 1997     Unfurnished        0               22      7            13
# 1998  Semi-Furnished        1               14     10            11
# 1999  Semi-Furnished        1               16      8            11
#
#              House_Type  Price_INR
# 0             Apartment   20132337
# 1     Independent House    2218954
# 2     Independent House   24140486
# 3     Independent House   16444877
# 4     Independent House   10363441
# ...                 ...        ...
# 1995              Villa   24931883
# 1996  Independent House   17424646
# 1997          Apartment   16394285
# 1998              Villa   24551549
# 1999  Independent House   17969096
#
# [2000 rows x 13 columns]

# %% [markdown]
# Basic Data Understanding

# %%
df.head(5)
# Out:
#   House_ID   Location  Bedrooms  Bathrooms  Balconies  Area_sqft  \
# 0    H0001    Kolkata         4          4          3       1398
# 1    H0002     Mumbai         3          4          2       1387
# 2    H0003       Pune         5          2          2       3395
# 3    H0004    Kolkata         1          4          3       3854
# 4    H0005  Hyderabad         5          4          2        808
#
#        Furnishing  Parking  Age_of_Property  Floor  Total_Floors  \
# 0  Semi-Furnished        2               14     14            12
# 1  Semi-Furnished        2                5      7             8
# 2  Semi-Furnished        2               26      4            19
# 3       Furnished        1               25      5            11
# 4  Semi-Furnished        0                3      8            14
#
#           House_Type  Price_INR
# 0          Apartment   20132337
# 1  Independent House    2218954
# 2  Independent House   24140486
# 3  Independent House   16444877
# 4  Independent House   10363441

# %%
df.shape
# Out:
# (2000, 13)

# %%
df.columns
# Out:
# Index(['House_ID', 'Location', 'Bedrooms', 'Bathrooms', 'Balconies',
#        'Area_sqft', 'Furnishing', 'Parking', 'Age_of_Property', 'Floor',
#        'Total_Floors', 'House_Type', 'Price_INR'],
#       dtype='object')

# %%
df.dtypes
# Out:
# House_ID           object
# Location           object
# Bedrooms            int64
# Bathrooms           int64
# Balconies           int64
# Area_sqft           int64
# Furnishing         object
# Parking             int64
# Age_of_Property     int64
# Floor               int64
# Total_Floors        int64
# House_Type         object
# Price_INR           int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# House_ID           0
# Location           0
# Bedrooms           0
# Bathrooms          0
# Balconies          0
# Area_sqft          0
# Furnishing         0
# Parking            0
# Age_of_Property    0
# Floor              0
# Total_Floors       0
# House_Type         0
# Price_INR          0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#           Bedrooms   Bathrooms    Balconies    Area_sqft      Parking  \
# count  2000.000000  2000.00000  2000.000000  2000.000000  2000.000000
# mean      3.039000     2.50300     1.517000  2322.867500     0.983500
# std       1.423901     1.12411     1.115497   994.441572     0.828596
# min       1.000000     1.00000     0.000000   601.000000     0.000000
# 25%       2.000000     1.00000     1.000000  1473.000000     0.000000
# 50%       3.000000     3.00000     2.000000  2321.500000     1.000000
# 75%       4.000000     4.00000     3.000000  3200.250000     2.000000
# max       5.000000     4.00000     3.000000  3998.000000     2.000000
#
#        Age_of_Property        Floor  Total_Floors     Price_INR
# count      2000.000000  2000.000000    2000.00000  2.000000e+03
# mean         14.648000     7.487500      12.03650  1.338740e+07
# std           8.501131     4.016829       4.38027  6.853226e+06
# min           0.000000     1.000000       5.00000  1.523439e+06
# 25%           7.000000     4.000000       8.00000  7.250237e+06
# 50%          15.000000     7.000000      12.00000  1.350834e+07
# 75%          22.000000    11.000000      16.00000  1.930819e+07
# max          29.000000    14.000000      19.00000  2.499638e+07

# %% [markdown]
# Exploratory Data Analysis

# %%
#bar graph between count of houses in each cities
city_counts=df['Location'].value_counts()
city_counts
plt.bar(city_counts.index,city_counts.values,color='red')
plt.xlabel('City')
plt.ylabel('Count')
plt.title('City Distribution')
plt.xticks(rotation=90)
plt.show()

# %%
#pie chart shows the percentage of house type among overall
house_type_counts=df['House_Type'].value_counts()
house_type_counts
plt.pie(house_type_counts.values,labels=house_type_counts.index,autopct='%1.1f%%')
plt.title('House Type Distribution')
plt.show()

# %%
#histogram shows the type of distributions
sns.histplot(df['Price_INR'], bins=20,kde=True, color='skyblue', edgecolor='black')
plt.title('Distribution of Price')
plt.xlabel('Price_INR')
plt.ylabel('Frequency')
plt.show()

# %%
sns.histplot(df['Area_sqft'], bins=20,kde=True, color='skyblue', edgecolor='black')
plt.title('Distribution of Area')
plt.xlabel('Area_sqft')
plt.ylabel('Frequency')

plt.show()

# %%
#boxplot shows the data how far
data = ['Price_INR']
plt.figure(figsize=(15, 8))
sns.boxplot(data=df[data])
plt.title("Boxplot of prices")
plt.xlabel("Values")
plt.ylabel("Price")
plt.show()

# %%
df.columns
# Out:
# Index(['House_ID', 'Location', 'Bedrooms', 'Bathrooms', 'Balconies',
#        'Area_sqft', 'Furnishing', 'Parking', 'Age_of_Property', 'Floor',
#        'Total_Floors', 'House_Type', 'Price_INR'],
#       dtype='object')

# %%
#shows the coorelation between two numerical variables
plt.scatter(df['Age_of_Property'], df['Price_INR'])
plt.xlabel('Age of Property')
plt.ylabel('Price (INR)')
plt.title('Scatter Plot of Price vs Age of Property')
plt.show()

# %%
correlation = df['Age_of_Property'].corr(df['Price_INR'])
print("Correlation:", correlation)
# Out:
# Correlation: -0.008359784758655677

# %%
#shows the coorelation of all features in a heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(df[['Bedrooms', 'Bathrooms', 'Balconies',
       'Area_sqft', 'Parking', 'Age_of_Property', 'Floor',
       'Total_Floors', 'Price_INR']].corr(),
            annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Feature Correlation Heatmap")
plt.show()

# %% [markdown]
# Feature Engineering

# %%
df
# Out:
#      House_ID   Location  Bedrooms  Bathrooms  Balconies  Area_sqft  \
# 0       H0001    Kolkata         4          4          3       1398
# 1       H0002     Mumbai         3          4          2       1387
# 2       H0003       Pune         5          2          2       3395
# 3       H0004    Kolkata         1          4          3       3854
# 4       H0005  Hyderabad         5          4          2        808
# ...       ...        ...       ...        ...        ...        ...
# 1995    H1996    Chennai         1          3          2       1319
# 1996    H1997  Bangalore         1          1          0        674
# 1997    H1998    Chennai         1          3          2       1893
# 1998    H1999    Kolkata         2          4          2       2522
# 1999    H2000    Chennai         2          2          0       3273
#
#           Furnishing  Parking  Age_of_Property  Floor  Total_Floors  \
# 0     Semi-Furnished        2               14     14            12
# 1     Semi-Furnished        2                5      7             8
# 2     Semi-Furnished        2               26      4            19
# 3          Furnished        1               25      5            11
# 4     Semi-Furnished        0                3      8            14
# ...              ...      ...              ...    ...           ...
# 1995       Furnished        0                2      4            14
# 1996  Semi-Furnished        2               21     14             8
# 1997     Unfurnished        0               22      7            13
# 1998  Semi-Furnished        1               14     10            11
# 1999  Semi-Furnished        1               16      8            11
#
#              House_Type  Price_INR
# 0             Apartment   20132337
# 1     Independent House    2218954
# 2     Independent House   24140486
# 3     Independent House   16444877
# 4     Independent House   10363441
# ...                 ...        ...
# 1995              Villa   24931883
# 1996  Independent House   17424646
# 1997          Apartment   16394285
# 1998              Villa   24551549
# 1999  Independent House   17969096
#
# [2000 rows x 13 columns]

# %%
df['Price_per_sqft']=df['Price_INR']/df['Area_sqft']
df['Price_per_sqft'].head(5)
# Out:
# 0    14400.813305
# 1     1599.822639
# 2     7110.599705
# 3     4266.963415
# 4    12826.040842
# Name: Price_per_sqft, dtype: float64

# %%
df['Bedroom_Area']=df['Bedrooms']*df['Area_sqft']
df['Bedroom_Area'].head(5)
# Out:
# 0     5592
# 1     4161
# 2    16975
# 3     3854
# 4     4040
# Name: Bedroom_Area, dtype: int64

# %%
df['Age_Category'] = pd.qcut(df['Age_of_Property'], q=3, labels=['New', 'Mid Age', 'Old'])
df['Age_Category'].head(5)
# Out:
# 0    Mid Age
# 1        New
# 2        Old
# 3        Old
# 4        New
# Name: Age_Category, dtype: category
# Categories (3, object): ['New' < 'Mid Age' < 'Old']

# %%
df['Total_Rooms'] = df['Bedrooms'] + df['Bathrooms'] + df['Balconies']
df['Total_Rooms'].head(5)
# Out:
# 0    11
# 1     9
# 2     9
# 3     8
# 4    11
# Name: Total_Rooms, dtype: int64
